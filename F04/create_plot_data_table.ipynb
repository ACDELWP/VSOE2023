# %%
from pandas import read_csv

# %%
data = read_csv('FF_20220829_1700.csv')

# %%
data.iloc[0]
# Out:
# GENER_DESC                                                CROWN
# MMTGEN        NATIONAL PARKS ACT AND NATURE CONSERVATION RES...
# AREA_HA                                              128.440577
# mer_plm_de                                   Parks and Reserves
# REG_NAME                                                    NaN
# bioregion                                                   NaN
# gridcode                                                      0
# FF_Des                                               Non Forest
# Name: 0, dtype: object

# %%
data.loc[data.loc[data.MMTGEN.isnull() == True].index.tolist(), 'MMTGEN'] = 'PRIVATE'

# %%
data.drop(
    index=data.loc[data.GENER_DESC == 'MARINE'].index.tolist(), 
    inplace=True
)

# %%
data.drop(
    index=data.loc[data.GENER_DESC.isnull() == True].index.tolist(), 
    inplace=True
)

# %% [markdown]
# Bioregion | Gridcode (1-5) | MMTGEN (plm 25) | Area Ha
#
# Grid code 1 - Patch | 2 - Transitional | 3 - Perforated | 4 - Edge | 5 - Interior | 0=nonforest

# %%
Parks reserves = NATIONAL PARKS ACT AND NATURE CONSERVATION RESERVES  

State forest = State forest + Plantation 

Others = Other public land + Other conservation + Commonwealth land

PRIVATE is private

# %%
•	Commonwealth Land, Other Public Land, Not Classified or unattributed = Other public land


•	Other Conservation Reserves & National Parks Act and Nature Conservation Reserves = National park
# Out:
#   File "C:\Users\ac4o\AppData\Local\Temp/ipykernel_24116/1772105210.py", line 1
#     •	Commonwealth Land, Other Public Land, Not Classified or unattributed = Other public land
#     ^
# SyntaxError: invalid character in identifier

# %%
data['label'] = ''
data.loc[data.MMTGEN == 'NATIONAL PARKS ACT AND NATURE CONSERVATION RESERVES', 'label'] = 'Parks & Reserves'
data.loc[data.MMTGEN == 'OTHER CONSERVATION RESERVES', 'label'] = 'Parks & Reserves'
data.loc[data.MMTGEN == 'STATE FOREST', 'label'] = 'State Forest'
data.loc[data.MMTGEN == 'PLANTATION', 'label'] = 'State Forest'
data.loc[data.MMTGEN == 'PRIVATE', 'label'] = 'Private'
data.loc[data.MMTGEN == 'COMMONWEALTH LAND', 'label'] = 'Other Crown Land'
data.loc[data.MMTGEN == 'OTHER PUBLIC LAND', 'label'] = 'Other Crown Land'

# %%
table_data = data[['bioregion', 'gridcode', 'label', 'AREA_HA']]

# %%
table_data.head()
# Out:
#   bioregion  gridcode             label     AREA_HA
# 0       NaN         0  Parks & Reserves  128.440577
# 1       NaN         0  Parks & Reserves    0.003618
# 2       NaN         0  Parks & Reserves    0.058283
# 3       NaN         0  Parks & Reserves    0.002629
# 4       NaN         0  Parks & Reserves    0.022649

# %%
table_data.bioregion.value_counts()
# Out:
# VICTORIAN MIDLANDS           43759
# SOUTH EASTERN HIGHLANDS      28363
# RIVERINA                     20371
# SOUTH EAST COASTAL PLAIN     18515
# MURRAY DARLING DEPRESSION    16903
# VICTORIAN VOLCANIC PLAIN     11975
# SOUTH EAST CORNER             8621
# NSW SOUTH WESTERN SLOPES      6297
# NARACOORTE COASTAL PLAIN      3225
# AUSTRALIAN ALPS               2198
# FLINDERS                       532
# Name: bioregion, dtype: int64

# %%
table_data.drop(
    index=table_data.loc[table_data.gridcode == 0].index.tolist(), 
    inplace=True
)
# Out:
# C:\Users\ac4o\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
table_data.drop(
    index=table_data.loc[table_data.bioregion.isnull() == True].index.tolist(), 
    inplace=True
)

# %%
table_plot_data_name = 'table_plot_data.csv'

# %%
with open(table_plot_data_name, 'w') as w:
    header = 'bioregion,gridcode,label,local_area,local_area_pct,sum_area\n'
    w.writelines(header)

# %%
for bioregion in table_data.bioregion.unique():
    subset = table_data.loc[table_data.bioregion == bioregion]
    for label in table_data.label.unique():
        sum_area = subset.loc[subset.label == label].AREA_HA.sum()
        for gridcode in table_data.gridcode.unique():
            local_area = subset.loc[(subset.gridcode == gridcode) & 
                                        (subset.label == label)
                                       ].AREA_HA.sum()
            # 'bioregion,gridcode,gridcode_name,MMGTGEN,local_area,local_area_pct,sum_area\n'
            output_line = f'{bioregion},{gridcode},{label},{local_area},{local_area/sum_area},{sum_area}\n'
            with open(table_plot_data_name, 'a') as a:
                a.writelines(output_line)
                print(output_line)
# Out:
# NARACOORTE COASTAL PLAIN,1,Parks & Reserves,1155.9817455722798,0.01965007962419266,58828.34918129622
#
# NARACOORTE COASTAL PLAIN,2,Parks & Reserves,2687.5411977069302,0.04568445715558856,58828.34918129622
#
# NARACOORTE COASTAL PLAIN,3,Parks & Reserves,28462.05406063847,0.48381527710261923,58828.34918129622
#
# NARACOORTE COASTAL PLAIN,4,Parks & Reserves,2666.9398744276,0.04533426335334805,58828.34918129622
#
# NARACOORTE COASTAL PLAIN,5,Parks & Reserves,23855.832302950934,0.40551592276425147,58828.34918129622
#
# NARACOORTE COASTAL PLAIN,1,Private,18.160929865599996,0.0671042585746098,270.63751617801995
#
# NARACOORTE COASTAL PLAIN,2,Private,64.06754763456,0.23672825755767596,270.63751617801995
#
# NARACOORTE COASTAL PLAIN,3,Private,124.72234012945,0.4608464557715278,270.63751617801995
#
# NARACOORTE COASTAL PLAIN,4,Private,11.78134079896,0.043531809504231744,270.63751617801995
#
# NARACOORTE COASTAL PLAIN,5,Private,51.90535774945,0.19178921859195489,270.63751617801995
#
# NARACOORTE COASTAL PLAIN,1,State Forest,344.47960995383005,0.004131323495680012,83382.385890149
#
# NARACOORTE COASTAL PLAIN,2,State Forest,1819.94050844486,0.02182643839002779,83382.385890149
#
# NARACOORTE COASTAL PLAIN,3,State Forest,43492.2482177212,0.5215999488791251,83382.385890149
#
# NARACOORTE COASTAL PLAIN,4,State Forest,4037.68032299638,0.048423660223824334,83382.385890149
#
# NARACOORTE COASTAL PLAIN,5,State Forest,33688.03723103274,0.40401862901134283,83382.385890149
#
# NARACOORTE COASTAL PLAIN,1,Other Crown Land,283.35450333293,0.08152126991991197,3475.83524657188
#
# NARACOORTE COASTAL PLAIN,2,Other Crown Land,350.36127004957,0.10079915910718773,3475.83524657188
#
# NSW SOUTH WESTERN SLOPES,4,Other Crown Land,24.937550888659995,0.010100884684616987,2468.84819174684
#
# NSW SOUTH WESTERN SLOPES,5,Other Crown Land,99.28599116071999,0.0402155108169976,2468.84819174684
#
# FLINDERS,1,Parks & Reserves,1246.0285210003003,0.04721348021632567,26391.37202534465
#
# FLINDERS,2,Parks & Reserves,2239.0006983778503,0.08483835915115182,26391.37202534465
#
# FLINDERS,3,Parks & Reserves,13245.390427364247,0.5018833584947455,26391.37202534465
#
# FLINDERS,4,Parks & Reserves,691.83109153225,0.02621429044567512,26391.37202534465
#
# FLINDERS,5,Parks & Reserves,8969.12128707,0.3398505116921018,26391.37202534465
#
# FLINDERS,1,Private,0.0,0.0,0.00135466694
#
# FLINDERS,2,Private,0.00135466694,1.0,0.00135466694
#
# FLINDERS,3,Private,0.0,0.0,0.00135466694
#
# FLINDERS,4,Private,0.0,0.0,0.00135466694
#
# FLINDERS,5,Private,0.0,0.0,0.00135466694
#
# FLINDERS,1,State Forest,0.0,nan,0.0
#
# FLINDERS,2,State Forest,0.0,nan,0.0
#
# FLINDERS,3,State Forest,0.0,nan,0.0
#
# FLINDERS,4,State Forest,0.0,nan,0.0
#
# FLINDERS,5,State Forest,0.0,nan,0.0
#
# FLINDERS,1,Other Crown Land,0.0,nan,0.0
#
# FLINDERS,2,Other Crown Land,0.0,nan,0.0
#
# FLINDERS,3,Other Crown Land,0.0,nan,0.0
#
# FLINDERS,4,Other Crown Land,0.0,nan,0.0
#
# FLINDERS,5,Other Crown Land,0.0,nan,0.0
#
# AUSTRALIAN ALPS,1,Parks & Reserves,948.44799638135,0.0026866051818305635,353028.4251648428
#
# AUSTRALIAN ALPS,2,Parks & Reserves,2329.94053016946,0.006599866651195352,353028.4251648428
#
# AUSTRALIAN ALPS,3,Parks & Reserves,58860.60177842842,0.1667304884895433,353028.4251648428
#
# AUSTRALIAN ALPS,4,Parks & Reserves,6205.891426778509,0.01757901342896322,353028.4251648428
#
# AUSTRALIAN ALPS,5,Parks & Reserves,284683.5434330851,0.8064040262484676,353028.4251648428
#
# AUSTRALIAN ALPS,1,Private,0.13560874614,0.0011823066889164891,114.69845126586998
#
# AUSTRALIAN ALPS,2,Private,0.95828412168,0.008354813086871644,114.69845126586998
#
# AUSTRALIAN ALPS,3,Private,20.962320323410005,0.18276027350028934,114.69845126586998
#
# AUSTRALIAN ALPS,4,Private,2.4447401649499994,0.02131450022183049,114.69845126586998
#
# AUSTRALIAN ALPS,5,Private,90.19749790968999,0.7863881065020921,114.69845126586998
#
# AUSTRALIAN ALPS,1,State Forest,4.2769750661299994,1.2728308817945067e-05,336020.6864324415
#
# AUSTRALIAN ALPS,2,State Forest,79.70714108003,0.00023720902997457414,336020.6864324415
#
# AUSTRALIAN ALPS,3,State Forest,18221.437038582742,0.05422712878793623,336020.6864324415
#
# AUSTRALIAN ALPS,4,State Forest,2033.2961943306998,0.006051104221940524,336020.6864324415
#
# AUSTRALIAN ALPS,5,State Forest,315681.96908338193,0.9394718296513308,336020.6864324415
#
# AUSTRALIAN ALPS,1,Other Crown Land,1.29001144222,0.007381376848220659,174.76569327726003
#
# AUSTRALIAN ALPS,2,Other Crown Land,14.52597994242,0.08311688449846395,174.76569327726003
#
# AUSTRALIAN ALPS,3,Other Crown Land,71.80547711467,0.41086712024626576,174.76569327726003
#
# AUSTRALIAN ALPS,4,Other Crown Land,23.239151390849997,0.1329731880156928,174.76569327726003
#
# AUSTRALIAN ALPS,5,Other Crown Land,63.905073387099996,0.3656614303913566,174.76569327726003
#
# SOUTH EAST CORNER,1,Parks & Reserves,912.6899736323799,0.0021720860489489124,420190.523333105
#
# SOUTH EAST CORNER,2,Parks & Reserves,2009.72272215564,0.004782884454922457,420190.523333105
#
# SOUTH EAST CORNER,3,Parks & Reserves,54381.79614502829,0.12942175781036655,420190.523333105
#
# SOUTH EAST CORNER,4,Parks & Reserves,4643.471783100899,0.011050872224026334,420190.523333105
#
# SOUTH EAST CORNER,5,Parks & Reserves,358242.8427091879,0.8525723994617359,420190.523333105
#
# SOUTH EAST CORNER,1,Private,50.15646350128,0.036286644965739856,1382.2292898292299
#
# SOUTH EAST CORNER,2,Private,123.78762159998,0.08955650304246814,1382.2292898292299
#
# SOUTH EAST CORNER,3,Private,612.00643177287,0.44276766255508987,1382.2292898292299
#
# SOUTH EAST CORNER,4,Private,50.26234437517,0.036363246492468526,1382.2292898292299
#
# SOUTH EAST CORNER,5,Private,546.01642857993,0.39502594294423365,1382.2292898292299
#
# SOUTH EAST CORNER,1,State Forest,166.38349310682,0.00024191772121156892,687768.9334768058
#
# SOUTH EAST CORNER,2,State Forest,1790.32237607677,0.0026030870092173864,687768.9334768058
#
# SOUTH EAST CORNER,3,State Forest,80651.39250079266,0.11726524501925985,687768.9334768058
#
# SOUTH EAST CORNER,4,State Forest,5357.50169655125,0.00778968260381875,687768.9334768058
#
# SOUTH EAST CORNER,5,State Forest,599803.3334102784,0.8721000676464926,687768.9334768058
#
# SOUTH EAST CORNER,1,Other Crown Land,845.9741344879801,0.1416697375543278,5971.452683489049
#
# SOUTH EAST CORNER,2,Other Crown Land,856.7073551323899,0.14346715959102702,5971.452683489049
#
# SOUTH EAST CORNER,3,Other Crown Land,2599.14570045481,0.4352618765014077,5971.452683489049
#
# SOUTH EAST CORNER,4,Other Crown Land,162.63714040007,0.027235774780525104,5971.452683489049
#
# SOUTH EAST CORNER,5,Other Crown Land,1506.9883530138002,0.25236545157271256,5971.452683489049
# C:\Users\ac4o\AppData\Local\Temp/ipykernel_24116/671610957.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   output_line = f'{bioregion},{gridcode},{label},{local_area},{local_area/sum_area},{sum_area}\n'

# %%
table_data.MMTGEN.unique()
# Out:
# array(['NATIONAL PARKS ACT AND NATURE CONSERVATION RESERVES', 'PRIVATE',
#        'STATE FOREST', 'OTHER PUBLIC LAND', 'OTHER CONSERVATION RESERVES',
#        'PLANTATION', 'COMMONWEALTH LAND'], dtype=object)
